# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import pandas as pd

# %%
arquivo = pd.read_csv('arquivos/dados_dengue.csv')
anos = arquivo[['ano']]
casos = arquivo[['casos']]

# %%
regr = LinearRegression()
regr.fit(X=anos, y=casos)
# Out:
# LinearRegression()

# %%
ano_futuro = [[2018]]
casos_2018 = regr.predict(ano_futuro)

print('Casos previstos para 2018 ->', int(casos_2018))
# Out:
# Casos previstos para 2018 -> 330
# /home/bluee/micromamba/envs/ml/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /tmp/ipykernel_13739/3188437172.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('Casos previstos para 2018 ->', int(casos_2018))

# %%
plt.scatter(anos, casos, color='black')
plt.scatter(ano_futuro, casos_2018, color='red')
plt.plot(anos, regr.predict(anos), color='blue')

plt.xlabel('Anos')
plt.ylabel('Casos de dengue')
plt.xticks([2018])
plt.yticks([int(casos_2018)])

plt.show()
# Out:
# /tmp/ipykernel_13739/4226713907.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   plt.yticks([int(casos_2018)])
